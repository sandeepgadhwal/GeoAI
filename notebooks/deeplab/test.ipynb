# %%
from pathlib import Path
from mmengine.config import Config

# %%
prefix = Path('../../configs/deeplab')

# %%
c = Config.fromfile(prefix / 'deeplab.py')

# %%
print(c.pretty_text)
# Out:
# norm_cfg = dict(type='SyncBN', requires_grad=True, _scope_='mmseg')
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         769,
#         769,
#     ),
#     _scope_='mmseg')
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             769,
#             769,
#         )),
#     pretrained='torchvision://resnet18',
#     backbone=dict(
#         type='ResNet',
#         depth=18,
# ...
