# %%
# %load_ext autoreload
# %autoreload 2

# %%
from geoai.data.cloud_masks import CloudMaskDataset

# %%
ds = CloudMaskDataset(
    '/home/sandeep/workspace/competitions/MaskingCloudsinSatelliteImageries/data', 
    256,
    image_dir="train_true_color",
    mask_dir="train_mask"
)
# Out:
# Prepared Dataset: (999/1000) /home/sandeep/workspace/competitions/MaskingCloudsinSatelliteImageries/data/train_true_color/train_true_color_127.tif filtered (3/16)

# %%
len(ds)
# Out:
# 7357

# %%
stats = ds.get_stats()

# %%
stats
# Out:
# {'image_stats': {'mean': array([2315.3093, 2460.9182, 2424.4849], dtype=float32),
#   'std': array([1370.4095, 1372.0483, 1484.2986], dtype=float32)}}

# %%
ds.datasets[0].dataset.metainfo
# Out:
# {'classes': ['background', 'cloud'], 'palette': [[0, 0, 0], [245, 66, 66]]}

# %%
ds[10].plot(percent_clip=[0, 98])
# Out:
# <Axes: >

# %%
ds[4].plot(percent_clip=[0, 98])
# Out:
# <Axes: >
