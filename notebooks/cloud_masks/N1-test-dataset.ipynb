# %%
# %load_ext autoreload
# %autoreload 2

# %%
from geoai.data.cloud_masks import CloudMaskDataset

# %%
ds = CloudMaskDataset('/home/sandeep/workspace/competitions/Masking Clouds in Satellite Imageries', 256)
# Out:
# Prepared Dataset: (999/1000) /home/sandeep/workspace/competitions/Masking Clouds in Satellite Imageries/train_true_color/train_true_color_127.tif filtered (3/16)

# %%
ds.datasets[0].dataset.metainfo
# Out:
# {'classes': ['background', 'cloud'], 'palette': [[0, 0, 0], [245, 66, 66]]}

# %%
ds[10].plot()
# Out:
# 0.0 1.0
# <Axes: >

# %%
ds[4].plot()
# Out:
# <Axes: >
