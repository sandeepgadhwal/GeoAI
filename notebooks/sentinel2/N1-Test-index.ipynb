# %%
# %load_ext autoreload
# %autoreload 2

# %%
from geoai.data.sentinel import refresh_index

# %%
refresh_index()

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/sandeep/.GeoAI/sentinel/sentinel2/index.csv.gz', skiprows=range(1, 10000000), nrows=20000)

# %%
df
# Out:
#                                GRANULE_ID  \
# 0      L2A_T23XNC_A021901_20190901T150911
# 1      L2A_T04WFT_A026810_20200809T220536
# 2      L2A_T51QVF_A032490_20230527T022738
# 3      L2A_T12TYT_A014553_20191219T181747
# 4      L2A_T52PBQ_A020492_20210207T020444
# ...                                   ...
# 19995  L2A_T14WMV_A035302_20220326T182240
# 19996  L2A_T47NNG_A032519_20210913T034206
# 19997  L2A_T42CWD_A020979_20210313T034818
# 19998  L2A_T18TWP_A031297_20230304T160904
# 19999  L2A_T14WNB_A024820_20200323T181010
#
#                                               PRODUCT_ID  \
# 0      S2A_MSIL2A_20190901T150911_N0213_R025_T23XNC_2...
# 1      S2A_MSIL2A_20200809T220541_N0214_R072_T04WFT_2...
# 2      S2B_MSIL2A_20230527T021539_N0509_R003_T51QVF_2...
# 3      S2B_MSIL2A_20191219T181749_N0213_R084_T12TYT_2...
# 4      S2B_MSIL2A_20210207T020449_N0214_R017_T52PBQ_2...
# ...                                                  ...
# ...
